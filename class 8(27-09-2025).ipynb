# %%
fullname = 'sahil mobeen'

# %%
fullname.count('e')
# Out:
# 2

# %%
fullname
# Out:
# 'sahil mobeen'

# %%
info = 'my name is sahil mobeen , i live in lahore and lahore is a beautiful city i donot want to leave lahore'

# %%
info
# Out:
# 'my name is sahil mobeen , i live in lahore and lahore is a beautiful city i donot want to leave lahore'

# %%
start = info.find('i live')

# %%
info.count('lahore')
# Out:
# 3

# %%
end=  info.find('city') + len('city') -1
# Out:
# 72

# %%
#info[start : end+1] start=inclusive, end = exclusive (you need to add 1)
info[start : end  +1]
# Out:
# 'i live in lahore and lahore is a beautiful city'

# %%
info
# Out:
# 'my name is sahil mobeen , i live in lahore and lahore is a beautiful city i donot want to leave lahore'

# %%
all_names = 'sahil , mobeen , sumair'

# %%
fname = 'sahil'
sname = 'mobeen'
tname = 'sumair'

# %% [markdown]
# # list

# %%
all_names = ['sahil', 'sumair', 'mobeen', 'ali' , 'waseem']

# %%
type(all_names)
# Out:
# list

# %%
all_names
# Out:
# ['sahil', 'sumair', 'mobeen', 'ali', 'waseem']

# %% [markdown]
# # string slicing

# %%
all_names[0]
# Out:
# 'sahil'

# %%
type(all_names[3])
# Out:
# str

# %% [markdown]
# # slicing list

# %%
all_names[1 : 4 ]
# Out:
# ['sumair', 'mobeen', 'ali']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
all_names[0:3]
# Out:
# ['sahil', 'sumair', 'mobeen']

# %%
all_names[0 :4:2]
# Out:
# ['sahil', 'mobeen']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
all_names[-1]
# Out:
# 'waseem'

# %%
sliced_list=all_names[0:3]
sliced_list[::-1]
# Out:
# ['mobeen', 'sumair', 'sahil']

# %%
info[::1]
# Out:
# 'my name is sahil mobeen , i live in lahore and lahore is a beautiful city i donot want to leave lahore'

# %%
value = input('enter anything but it will be limit to 6 characters')[0:7]

# %%
value
# Out:
# 'my name'

# %%
value
# Out:
# 'my name'

# %%
type(all_names)
# Out:
# list

# %%
all_names
# Out:
# ['sahil', 'sumair', 'mobeen', 'ali', 'waseem']

# %%
all_names.append('Babar azam')

# %%
# use append() to add element
all_names
# Out:
# ['sahil', 'sumair', 'mobeen', 'ali', 'waseem', 'Babar azam']

# %%
all_names.append('fakhar')

# %%
cric = input('enter crickter name')

# %%
cric
# Out:
# 'babar'
