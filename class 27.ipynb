# %%
class User:
    def __init__ (self,  first_name, last_name, gender, age, campus = "SMIT" ):
        self.first_name = first_name
        self.last_name = last_name
        self.gender = gender
        self.age = age
        self.campus = campus
    def describe_user(self):
        print (f" User's name is {self.first_name} {self.last_name} \nAge: {self.age}\nGender {self.gender} \nCampus: {self.campus}")

    def greet_user (self):
        print (f'hello {self.first_name} welcome to our page')

# %%
kashan = User('kashan', 'khan', 'Male' ,20)
yaman = User('yaman', 'peshawari', 'Male', 10)
gahfar = User('Ghafar', 'swati', 'Male', 12)

# %%
kashan.first_name
# Out:
# 'kashan'

# %%
kashan.last_name
# Out:
# 'khan'

# %% [markdown]
# # Direct assignment (=)

# %%
kashan.first_name = 'shaikh'

# %%
kashan.first_name
# Out:
# 'shaikh'

# %%
kashan.__dict__
# Out:
# {'first_name': 'shaikh',
#  'last_name': 'khan',
#  'gender': 'Male',
#  'age': 20,
#  'campus': 'SMIT'}

# %% [markdown]
# # Using seeter and gether methods (custom methods)

# %%
class User:
    def __init__ (self,  first_name, last_name, gender, age, campus = "SMIT" ):
        self.first_name = first_name
        self.last_name = last_name
        self.gender = gender
        self.age = age
        self.campus = campus
        
    def change_campus (self, new_campus):
        self.campus = new_campus
    
    def show_campus (self) :
        return self.campus    

    def describe_user(self):
        print (f" User's name is {self.first_name} {self.last_name} \nAge: {self.age}\nGender {self.gender} \nCampus: {self.campus}")

    def greet_user (self):
        print (f'hello {self.first_name} welcome to our page')

# %%
kashan = User('kashan', 'khan', 'Male' ,20)
yaman = User('yaman', 'peshawari', 'Male', 10)
gahfar = User('Ghafar', 'swati', 'Male', 12)

# %%
kashan.change_campus('JDC')  #setter

# %%
kashan.show_campus() #getter
# Out:
# 'JDC'

# %%
class User:
    def __init__ (self ,first_name, last_name, gender, age, campus="SMIT"):
        self.first_name = first_name
        self.last_name = last_name
        self.age = age
        self.gender = gender
        self.campus = campus
    def change_details(self, new_first_name='', new_last_name='', new_age=None, new_gender ='', new_campus =''):
        if new_first_name :
            self.first_name = new_first_name
        if new_last_name:
            self.last_name = new_last_name  
        if new_age :
            self.age = new_age
        if new_gender :
            self.gender =new_gender
        if new_campus :
            self.campus = new_campus   

    def show_campus(self):
        return self.campus
        
    def describe_user(self):
        print(f"User's name is {self.first_name} {self.last_name}\nAge: {self.age}\nGender: {self.gender}\nCampus: {self.campus}")

    def greet_user(self):
        print(f'Hello {self.first_name}Welcome to our page')

# %%
kashan = User('kashan', 'khan', 'Male' ,20)
yaman = User('yaman', 'peshawari', 'Male', 10)
gahfar = User('Ghafar', 'swati', 'Male', 12)

# %%
kashan.change_details('sahil','mobeen')

# %%
kashan.__dict__
# Out:
# {'first_name': 'sahil',
#  'last_name': 'mobeen',
#  'age': 20,
#  'gender': 'Male',
#  'campus': 'SMIT'}

# %%
x
