# %%
cities = ['karachi,larkana, quetta ']

# %%
cities
# Out:
# ['karachi,larkana, quetta ']

# %%
cities.reverse()

# %%
cities
# Out:
# ['karachi,larkana, quetta ']

# %%
fruits = ['apple','grapes','banana' , 'mango']

# %%
fruits
# Out:
# ['apple', 'grapes', 'banana', 'mango']

# %%
fruits
# Out:
# ['apple', 'grapes', 'banana', 'mango']

# %%
fruits = fruits.coppy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 fruits = fruits.coppy()
#
# AttributeError: 'list' object has no attribute 'coppy'

# %%
copy_fruits
# Out:
# ['apple', 'banana', 'grapes', 'mango']

# %%
#append is add string in sentence

# %% [markdown]
# # copy by refrence

# %%
another_fruits= fruits

# %%
fruits
# Out:
# ['apple', 'banana', 'grapes', 'mango']

# %%
another_fruits.append('pear')

# %%
fruits
# Out:
# ['apple', 'banana', 'grapes', 'mango', 'pear']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cities = ['karachi','lahore','quetta','dadu']
another_cities= cities

# %%
another_cities
# Out:
# ['karachi', 'lahore', 'quetta', 'dadu']

# %%
cities = cities.sort()

# %%
print(id(fruits))
print(id(another_fruits))
print (id(copy_fruits))
# Out:
# 140722266960368
# 2547580658752
# 2547581928832

# %% [markdown]
# # split and join

# %%
email = 'sahilmobeen@gmail.com'
email
# Out:
# 'sahilmobeen@gmail.com'

# %%
email.split('@')[0]
# Out:
# 'sahilmobeen'

# %%
names = ['Amir', 'Bear', 'Charlton', 'Daman']
print(names[-1])
# Out:
# Daman

# %%
list1 = [11, 2, 23]
def new_func():
    list2 = [11, 2, 2]
    return list2

list2 = new_func()
print(list1 < list2)
# Out:
# False
