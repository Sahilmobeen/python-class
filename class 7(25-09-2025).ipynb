# %%
fname = input('enter your first name').strip()
lname = input('enter your last name').strip()
print(f'my first name is {fname} and last name is {lname}')
# Out:
# my first name is sahil and last name is mobeen

# %% [markdown]
# # space removing in string
# - rstrip()
# - lstrip()

# %%
country = 'pakistan   '.rstrip()#for space removing

country
# Out:
# 'pakistan'

# %%
info = 'my name is sahil i lives in karachi'

# %%
info.replace('karachi', 'sialkot')
# Out:
# 'my name is sahil i lives in sialkot'

# %%
info.replace(' karachi','sialkot').replace('sahil','sumair')
info
# Out:
# 'my name is sahil i lives in karachi'

# %%
info.find('karachi')
# Out:
# 36

# %%
info = 'my name is sahil mobeen, i live in lahore and karachi is a beautiful city'

# %%
info
# Out:
# 'my name is sahil mobeen, i live in lahore and karachi is a beautiful city'

# %%
info.find('karachi')
# Out:
# 46

# %%
info.rfind('karachi')#right side
# Out:
# 46

# %%
info.index("karachi")
# Out:
# 46

# %%
info.find("lahore", )
# Out:
# 35

# %%
info.find('city')
# Out:
# 69
