# %%
# write a function is_anagram
#output
# 'foefet' is anagram of 'toffe'
# 'Buckethead' is an anagram of 'deathCubeK'

# %%
print = sorted(('Tofee'))
print
# Out:
# ['T', 'e', 'e', 'f', 'o']

# %%
def is_anagram(test , original):
    test = sorted(test.lower())
    original = sorted(original.lower())
    
    return test == original

# %%
is_anagram(' ' , 'tofee')
# Out:
# False

# %% [markdown]
# homework

# %%
# how to solve this without sorted

# %%
animals = ['sheep', 'sheep', 'wolf', 'sheep' , 'sheep']

# %%
result = []
value = 'apple ban'.split(' ')
for val in value:
    result.append(f'{val} {len(val)}')

# %%
def add_lenght(str_):
    result =[]
    splitted =str_.split(' ')
    for val in value:
    result.append(f'{val} {len(val)}')
