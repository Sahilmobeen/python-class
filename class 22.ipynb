# %%
def calculator(op , a , b):
    return eval(f' a {op} b')

# %%
calculator('+',2, 3)
# Out:
# 5

# %%
a =3 
eval('2 + a')
# Out:
# 5

# %% [markdown]
# self assissment

# %%
num = '[1 , 2 , 3, 4 , 5 , 6]'

# %%
type(num)
# Out:
# str

# %%
def calculator(op , a , b):
    try:
       print  (eval(f' a {op} b')) 
    except Exception as e:
         print (e)
    else:
         print ('Try run,  no exception')
    finally:
         print ('ye lazmi chale ga')

# %%
calculator('+', 2 , 3)
# Out:
# 5
# Try run,  no exception
# ye lazmi chale ga

# %%
calculator('_','a' ,3)
# Out:
# invalid syntax (<string>, line 1)
# ye lazmi chale ga

# %%
def foo():
    try:
        return 1
    finally:
       return 2
k = foo()
print(k)
# Out:
# 2

# %% [markdown]
# - Explanation: in Python, if both the try block and the finally block contain
# return statements, the return in thr finally block overridse

# %%
def foo():
    try:
        print(1)
    finally:
        print(2)
foo()
# Out:
# 1
# 2

# %%
'1'==1
# Out:
# False

# %% [markdown]
# # File
