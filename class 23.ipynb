# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open ('practice.text')

# %%
f
# Out:
# <_io.TextIOWrapper name='practice.text' mode='r' encoding='cp1252'>

# %%
content = f.read

# %%
print (content)
# Out:
# <built-in method read of _io.TextIOWrapper object at 0x000001E0D7398820>

# %%
print (type(content))
# Out:
# <class 'builtin_function_or_method'>

# %%
f.close()

# %%
print (content)
# Out:
# <built-in method read of _io.TextIOWrapper object at 0x000001E0D7398820>
