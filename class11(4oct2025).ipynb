# %% [markdown]
# # DICTIONARY

# %%
# info = {'key : 'value'}
info = {'name': 'sahil', 'course':'python','age':15}

# %%
info
# Out:
# {'name': 'sahil', 'course': 'python', 'age': 15}

# %%
print (type(info))
# Out:
# <class 'dict'>

# %%
info
# Out:
# {'name': 'sahil', 'course': 'python', 'age': 15}

# %%
data = {
    'virat kohli' : 'of side delivery',
    'babar azam ' : 'cricket ',
    'haris rauf' : 'bowling',
    10: 'shahid afridi',

}

# %%
info
# Out:
# {'name': 'sahil', 'course': 'python', 'age': 15}

# %% [markdown]
# # add key  value in dictionary

# %%
info['city'] = 'karachi'
info
# Out:
# {'name': 'sahil', 'course': 'python', 'age': 15, 'city': 'karachi'}

# %%
info['name']
# Out:
# 'sahil'

# %%
info.update({'campus': 'gulshan','city':'karachi'})
info
# Out:
# {'name': 'sahil',
#  'course': 'python',
#  'age': 15,
#  'city': 'karachi',
#  'campus': 'gulshan'}

# %% [markdown]
# # How to remove a value from a dictionary

# %%
info
# Out:
# {'name': 'sahil',
#  'course': 'python',
#  'age': 15,
#  'city': 'karachi',
#  'campus': 'gulshan'}

# %%
info.get('Topi')

info
# Out:
# {'name': 'sahil',
#  'course': 'python',
#  'age': 15,
#  'city': 'karachi',
#  'campus': 'gulshan'}
