# %%
info = 'This is a sentence'

# %%
info
# Out:
# 'This is a sentence'

# %%
type(info)
# Out:
# str

# %%
number= 10

# %%
info
# Out:
# 'This is a sentence'

# %%
info = info.upper()

# %%
info
# Out:
# 'THIS IS A SENTENCE'

# %%
info= info.lower()

# %%
info
# Out:
# 'this is a sentence'

# %%
info.title()
# Out:
# 'This Is A Sentence'

# %%
info.capitalize()
# Out:
# 'This is a sentence'

# %%
fullname=input('enter your full name').title()
               
fullname
# Out:
# 'Sahil Mobeen'

# %%
fullname
# Out:
# 'Sahil Mobeen'

# %%
fullname.isupper()
# Out:
# False

# %%
fullname.islower()
# Out:
# False

# %%
fullname.istitle()
# Out:
# True

# %%
fullname.startswith('s')
# Out:
# False

# %%
fullname.startswith('S')
# Out:
# True

# %%
fullname.endswith('n')
# Out:
# True

# %%
char=input('enter your letter? ').upper()
char
# Out:
# '@'

# %%
type(char)
# Out:
# str

# %%
fname= input('enter your first name').title()
fname
# Out:
# 'Sahil Mobeen'
