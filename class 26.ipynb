# %% [markdown]
# # OOPs

# %%
name =  'pakistan'
print (type(name))
# Out:
# <class 'str'>

# %%
class Car():
    make = 'Honda'
    model = 'Civic'
    year = 2020

# %%
car1 = Car()

# %%
car1.make
# Out:
# 'Honda'

# %%
car1.model
# Out:
# 'Civic'

# %%
#_init_ (constructor / initializer)

# %%
class Car1():
    def __inint__(self, make, model, year):
        self.make = make
        self.model  = model
        self.year = year

# %%
class Car:
    def __init__(self, make, model, year):
        #atributes
        self.make = make
        self.model = model
        self.year = year
        #Method
        def apply_accelerator(self):
            print ('Accelerator is applied')

        def apply_breaks(self):
            print ('Breaks are applied')

# %%
new_car = Car('Honda' , 'civic' , 2020)

# %%
new_car.apply_breaks()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 new_car.apply_breaks()
#
# AttributeError: 'Car' object has no attribute 'apply_breaks'

# %%
new_car.apply_accelerator()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 new_car.apply_accelerator()
#
# AttributeError: 'Car' object has no attribute 'apply_accelerator'

# %% [markdown]
# - problems:

# %%
class Resturent():
    def __init__(self, restaurant_name, cuisine_name):
        self.restaurant_type = restaurant_name
        self.cuisine_type = cuisine_name
        # method
    def describe(self):
        print(f'{self}')

# %%
class User:
    def __init__(self , first_name, last_name):
        self.first_name = first_name
        self.last_name = last_name
        self.full_name = f"{first_name} , {last_name}"

        def describe(self):
            print(f'First name is {self.first_name} and last name is {self.last_name} ')

            def greet(self):
                print (f'Hello {self.first_name} {self.last_name},Welcome to our show')
